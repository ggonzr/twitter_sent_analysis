# %% [markdown]
# # Limpieza del CSV
#
# Ya con los datos en la base documental en Mongo procedemos a extraer el .csv. Mongo, al exportar los documentos a .csv, tiene un pequeño error
# tratando la cadena "0" y lo saca con el valor de false.

# %%
# Librerias
import pandas as pd
import numpy as np

# %%
# Importar los datos
dataset = 'data/dbm-parsed.csv'
df = pd.read_csv(dataset, sep=';')
df.head(2)
# Out:
# C:\Users\Geovanny\.conda\envs\twitter\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (4,7,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                         _id  Sentiment  \
# 0  5fb1e9fcd31ed17108b92588          2
# 1  5fb1e9fcd31ed17108b92589          2
#
#                                            TweetText        TweetDatetime  \
# 0   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...  2020-11-15 18:33:28
# 1   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...  2020-11-15 18:33:28
#
#                TweetId    TwitterName UserLocation Userverified  \
# 0  1328043454639828994  ObsDemocracia          NaN        False
# 1  1328043454639828994  ObsDemocracia          NaN        False
#
#   TweetCoordinates PlaceInfo Retweets Favorites Language           Source  \
# 0             None      None        3     false       es  Twitter Web App
# 1             None      None        3     false       es  Twitter Web App
#
#   RepliedTweetId RepliedTweetUserIdStr QuoteStatusBool  \
# 0           None                  None           False
# 1           None                  None           False
#
#                                             hashtags
# 0  {'hashtags': [{'text': 'NoEsHoraDeCallar', 'in...
# 1  {'hashtags': [{'text': 'NoEsHoraDeCallar', 'in...

# %%
parsed_df = df[['Sentiment', 'TweetText', 'TweetDatetime', 'TweetId', 'TwitterName']]
parsed_df
# Out:
#         Sentiment                                          TweetText  \
# 0               2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 1               2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 2               2   "RT @Silviarjona: Imperdible esta entrevista ...
# 3               2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 4               2   "RT @Silviarjona: Imperdible esta entrevista ...
# ...           ...                                                ...
# 148386          4   "RT @ElVenecoCol: Uuyyy, Claudia... 💩. ¿En po...
# 148387          2   "Claudia López y los políticos xenófobos | La...
# 148388          2   "#6Nov 🇨🇴🇻🇪 | 🗣️ Para evitar la xenofobia, ve...
# 148389          4   "#Latinoamérica, la única región del mundo do...
# 148390          4   "Uuyyy, Claudia... 💩. ¿En política siempre re...
#
#                  TweetDatetime                 TweetId         TwitterName
# 0          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 1          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 2          2020-11-15 15:46:24     1328001413302063105         andrealdana
# 3          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 4          2020-11-15 15:46:24     1328001413302063105         andrealdana
# ...                        ...                     ...                 ...
# 148386   "2020-11-07 14:01:45"   "1325075975542099968"   "juanferestrepoh"
# 148387   "2020-11-07 12:47:41"   "1325057336088662017"   "JotaContrerasYA"
# 148388   "2020-11-06 23:34:45"   "1324857786858196996"   "fronteravivanew"
# 148389   "2020-11-06 21:01:44"   "1324819277879386112"    "PromedicaMujer"
# 148390   "2020-11-06 20:07:35"   "1324805649507717122"       "ElVenecoCol"
#
# [148391 rows x 5 columns]

# %% [markdown]
# Cambiar los nombres de las columnas

# %%
parsed_df = parsed_df.rename(columns={
    'Sentiment': 'target',
    'TweetText': 'text',
    'TweetId': 'ids',
    'TweetDatetime': 'date',
    'TwitterName': 'user'
})

# %%
parsed_df
# Out:
#         target                                               text  \
# 0            2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 1            2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 2            2   "RT @Silviarjona: Imperdible esta entrevista ...
# 3            2   "RT @CPolUniandes: #NoEsHoraDeCallar en colab...
# 4            2   "RT @Silviarjona: Imperdible esta entrevista ...
# ...        ...                                                ...
# 148386       4   "RT @ElVenecoCol: Uuyyy, Claudia... 💩. ¿En po...
# 148387       2   "Claudia López y los políticos xenófobos | La...
# 148388       2   "#6Nov 🇨🇴🇻🇪 | 🗣️ Para evitar la xenofobia, ve...
# 148389       4   "#Latinoamérica, la única región del mundo do...
# 148390       4   "Uuyyy, Claudia... 💩. ¿En política siempre re...
#
#                           date                     ids                user
# 0          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 1          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 2          2020-11-15 15:46:24     1328001413302063105         andrealdana
# 3          2020-11-15 18:33:28     1328043454639828994       ObsDemocracia
# 4          2020-11-15 15:46:24     1328001413302063105         andrealdana
# ...                        ...                     ...                 ...
# 148386   "2020-11-07 14:01:45"   "1325075975542099968"   "juanferestrepoh"
# 148387   "2020-11-07 12:47:41"   "1325057336088662017"   "JotaContrerasYA"
# 148388   "2020-11-06 23:34:45"   "1324857786858196996"   "fronteravivanew"
# 148389   "2020-11-06 21:01:44"   "1324819277879386112"    "PromedicaMujer"
# 148390   "2020-11-06 20:07:35"   "1324805649507717122"       "ElVenecoCol"
#
# [148391 rows x 5 columns]

# %% [markdown]
# Para culminar almacenamos el __.csv__ resultante

# %%
save_path = 'data/dbm-model.csv'
parsed_df.to_csv(path_or_buf=save_path, index=False, sep=';')
